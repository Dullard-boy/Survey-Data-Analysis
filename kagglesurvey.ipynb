# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv('C:/Users/hp/Desktop/Python Courses/kagglesurvey.csv')
data
# Out:
#        Respondent                                    WorkToolsSelect  \
# 0               1  Amazon Web services,Oracle Data Mining/ Oracle...
# 1               2  Amazon Machine Learning,Amazon Web services,Cl...
# 2               3  C/C++,Jupyter notebooks,MATLAB/Octave,Python,R...
# 3               4            Jupyter notebooks,Python,SQL,TensorFlow
# 4               5  C/C++,Cloudera,Hadoop/Hive/Pig,Java,NoSQL,R,Un...
# ...           ...                                                ...
# 10148       10149                                                NaN
# 10149       10150  C/C++,Hadoop/Hive/Pig,Java,Julia,Orange,Perl,R...
# 10150       10151                                                NaN
# 10151       10152                                                NaN
# 10152       10153                                             Python
#
#       LanguageRecommendationSelect EmployerIndustry  \
# 0                               F#   Internet-based
# ...

# %%
data.head()
# Out:
#    Respondent                                    WorkToolsSelect  \
# 0           1  Amazon Web services,Oracle Data Mining/ Oracle...
# 1           2  Amazon Machine Learning,Amazon Web services,Cl...
# 2           3  C/C++,Jupyter notebooks,MATLAB/Octave,Python,R...
# 3           4            Jupyter notebooks,Python,SQL,TensorFlow
# 4           5  C/C++,Cloudera,Hadoop/Hive/Pig,Java,NoSQL,R,Un...
#
#   LanguageRecommendationSelect EmployerIndustry  \
# 0                           F#   Internet-based
# 1                       Python    Mix of fields
# 2                       Python       Technology
# 3                       Python         Academic
# 4                            R       Government
#
#                                 WorkAlgorithmsSelect
# 0                Neural Networks,Random Forests,RNNs
# 1  Bayesian Techniques,Decision Trees,Random Fore...
# 2  Bayesian Techniques,CNNs,Ensemble Methods,Neur...
# 3  Bayesian Techniques,CNNs,Decision Trees,Gradie...
# ...

# %%
data.isnull()
# Out:
#        Respondent  WorkToolsSelect  LanguageRecommendationSelect  \
# 0           False            False                         False
# 1           False            False                         False
# 2           False            False                         False
# 3           False            False                         False
# 4           False            False                         False
# ...           ...              ...                           ...
# 10148       False             True                          True
# 10149       False            False                          True
# 10150       False             True                          True
# 10151       False             True                          True
# 10152       False            False                         False
#
#        EmployerIndustry  WorkAlgorithmsSelect
# 0                 False                 False
# 1                 False                 False
# ...

# %%
data.isnull().sum()
# Out:
# Respondent                         0
# WorkToolsSelect                 2198
# LanguageRecommendationSelect    3619
# EmployerIndustry                1155
# WorkAlgorithmsSelect            2852
# dtype: int64

# %%
data['LanguageRecommendationSelect'].isnull().value_counts()
# Out:
# False    6534
# True     3619
# Name: LanguageRecommendationSelect, dtype: int64

# %%
data['LanguageRecommendationSelect'].fillna('Unknown')
# Out:
# 0             F#
# 1         Python
# 2         Python
# 3         Python
# 4              R
#           ...
# 10148    Unknown
# 10149    Unknown
# 10150    Unknown
# 10151    Unknown
# 10152     Python
# Name: LanguageRecommendationSelect, Length: 10153, dtype: object

# %%
cleaned=data['LanguageRecommendationSelect'].fillna('Unknown')
cleaned.value_counts()
# Out:
# Python      4049
# Unknown     3619
# R           1670
# SQL          272
# C/C++/C#     142
# Matlab       122
# Scala         70
# Java          58
# SAS           50
# Other         48
# Julia         21
# Stata         18
# Haskell       12
# F#             2
# Name: LanguageRecommendationSelect, dtype: int64

# %%
data['EmployerIndustry'].value_counts()
# Out:
# Technology                          1839
# Academic                            1450
# Financial                            965
# Mix of fields                        825
# Other                                808
# Internet-based                       633
# Government                           474
# CRM/Marketing                        343
# Telecommunications                   308
# Manufacturing                        293
# Insurance                            266
# Retail                               256
# Pharmaceutical                       161
# Non-profit                           140
# Hospitality/Entertainment/Sports     124
# Military/Security                    113
# Name: EmployerIndustry, dtype: int64

# %%
clean=data['WorkAlgorithmsSelect'].fillna('Unknown Algorithm')
clean
# Out:
# 0                      Neural Networks,Random Forests,RNNs
# 1        Bayesian Techniques,Decision Trees,Random Fore...
# 2        Bayesian Techniques,CNNs,Ensemble Methods,Neur...
# 3        Bayesian Techniques,CNNs,Decision Trees,Gradie...
# 4                                        Unknown Algorithm
#                                ...
# 10148                                    Unknown Algorithm
# 10149                                    Unknown Algorithm
# 10150                                    Unknown Algorithm
# 10151                                    Unknown Algorithm
# 10152                                    Unknown Algorithm
# Name: WorkAlgorithmsSelect, Length: 10153, dtype: object

# %%
clean.value_counts()
# Out:
# Unknown Algorithm                                                                                                  2852
# Regression/Logistic Regression                                                                                      535
# Other                                                                                                               243
# Decision Trees,Random Forests,Regression/Logistic Regression                                                        205
# Decision Trees,Regression/Logistic Regression                                                                       201
#                                                                                                                    ...
# Bayesian Techniques,CNNs,Decision Trees,Gradient Boosted Machines,Random Forests,Regression/Logistic Regression       1
# Bayesian Techniques,CNNs,Evolutionary Approaches,GANs,HMMs,Neural Networks,RNNs,Other                                 1
# ...

# %%
grouped=data.groupby('EmployerIndustry')
for name,group in grouped:
    print(name)
    clgrp=group.fillna('Unknown')
    print(clgrp)
    print('')
# Out:
# Academic
#        Respondent                                    WorkToolsSelect  \
# 3               4            Jupyter notebooks,Python,SQL,TensorFlow
# 10             11          C/C++,Jupyter notebooks,Python,TensorFlow
# 12             13  C/C++,Java,Jupyter notebooks,MATLAB/Octave,Pyt...
# 32             33       IBM SPSS Modeler,IBM SPSS Statistics,R,Other
# 52             53  Amazon Web services,Jupyter notebooks,Python,R...
# ...           ...                                                ...
# 10093       10094  Amazon Web services,Java,Julia,Jupyter noteboo...
# 10110       10111                                            Unknown
# 10122       10123                                            Unknown
# 10130       10131                                            Unknown
# 10138       10139    Jupyter notebooks,NoSQL,Python,R,SQL,TensorFlow
#
#       LanguageRecommendationSelect EmployerIndustry  \
# 3                           Python         Academic
# ...

# %%
grouped=data.groupby('EmployerIndustry')
for name,group in grouped:
    print(name)
    clgrp=group.fillna('Unknown')
    print(clgrp['LanguageRecommendationSelect'].value_counts())
    print('')
# Out:
# Academic
# Python      616
# Unknown     399
# R           289
# Matlab       45
# C/C++/C#     40
# SQL          16
# Java         11
# Other        10
# Julia         7
# Scala         6
# SAS           4
# Stata         4
# Haskell       2
# F#            1
# Name: LanguageRecommendationSelect, dtype: int64
#
# CRM/Marketing
# Python      152
# Unknown      99
# R            64
# SQL           9
# Scala         6
# SAS           5
# Other         4
# Java          3
# C/C++/C#      1
# Name: LanguageRecommendationSelect, dtype: int64
#
# Financial
# Python      424
# Unknown     281
# R           170
# SQL          43
# C/C++/C#     13
# SAS          10
# Scala         9
# Java          5
# Other         4
# Matlab        4
# Julia         1
# Stata         1
# Name: LanguageRecommendationSelect, dtype: int64
#
# Government
# Python      174
# R           123
# Unknown     123
# SQL          21
# C/C++/C#      9
# SAS           6
# Matlab        5
# Java          4
# ...

# %%
grouped=data.groupby('EmployerIndustry')
for name,group in grouped:
    print(name)
    print('')
    clgrp=group.fillna('Unknown')
    print(clgrp['WorkToolsSelect'].value_counts())
    print('')
# Out:
# Academic
#
# Unknown                                                                               178
# Python,R                                                                               41
# R                                                                                      40
# Python                                                                                 26
# MATLAB/Octave                                                                          18
#                                                                                      ...
# C/C++,Python,R,Unix shell / awk                                                         1
# Java,R,SQL,TensorFlow,Other                                                             1
# C/C++,IBM SPSS Statistics,MATLAB/Octave,NoSQL,Python,TensorFlow                         1
# Microsoft Excel Data Mining,Minitab,R                                                   1
# ...

# %%
grouped=data.groupby('EmployerIndustry')
for name,group in grouped:
    print(name)
    clgrp=group.fillna('Unknown')
    new=clgrp['LanguageRecommendationSelect'].value_counts()
    print(pd.DataFrame(new).plot.bar())
    print('')
# Out:
# Academic
# AxesSubplot(0.125,0.125;0.775x0.755)
#
# CRM/Marketing
# AxesSubplot(0.125,0.125;0.775x0.755)
#
# Financial
# AxesSubplot(0.125,0.125;0.775x0.755)
#
# Government
# AxesSubplot(0.125,0.125;0.775x0.755)
#
# Hospitality/Entertainment/Sports
# AxesSubplot(0.125,0.125;0.775x0.755)
#
# Insurance
# AxesSubplot(0.125,0.125;0.775x0.755)
#
# Internet-based
# AxesSubplot(0.125,0.125;0.775x0.755)
#
# Manufacturing
# AxesSubplot(0.125,0.125;0.775x0.755)
#
# Military/Security
# AxesSubplot(0.125,0.125;0.775x0.755)
#
# Mix of fields
# AxesSubplot(0.125,0.125;0.775x0.755)
#
# Non-profit
# AxesSubplot(0.125,0.125;0.775x0.755)
#
# Other
# AxesSubplot(0.125,0.125;0.775x0.755)
#
# Pharmaceutical
# AxesSubplot(0.125,0.125;0.775x0.755)
#
# Retail
# AxesSubplot(0.125,0.125;0.775x0.755)
#
# Technology
# AxesSubplot(0.125,0.125;0.775x0.755)
#
# Telecommunications
# AxesSubplot(0.125,0.125;0.775x0.755)
